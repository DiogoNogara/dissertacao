# %% [markdown]
# Para o uso do código, é necessário possuir uma conta na plataforma Copernicus. Caso não possua, crie a mesma aqui: https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/auth?client_id=cdse-public&response_type=code&scope=openid&redirect_uri=https%3A//dataspace.copernicus.eu/account/confirmed/1

# %% [markdown]
# ##Download de pacotes

# %%
# 1. Instala pacotes necessários
# !pip install openeo geopandas shapely fiona --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 91.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 45.2 MB/s eta 0:00:00

# %% [markdown]
# ##Configurações

# %%
import openeo
import geopandas as gpd
from shapely.geometry import mapping
from datetime import datetime, timedelta
import os
from google.colab import drive
import shutil

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 1. Conectando à plataforma Copernicus Data Space com openEO - Clique no link e insira seu email e senha cadastrados na plataforma Copernicus
conn = openeo.connect("openeo.dataspace.copernicus.eu").authenticate_oidc()
# Out:
# Visit <a href="https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=RSBT-HWMB" title="Authenticate at https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=RSBT-HWMB" target="_blank" rel="noopener noreferrer">https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=RSBT-HWMB</a> <a href="#" onclick="navigator.clipboard.writeText('https://identity.dataspace.copernicus.eu/auth/realms/CDSE/device?user_code=RSBT-HWMB');return false;" title="Copy authentication URL to clipboard">&#128203;</a> to authenticate.
# ✅ Authorized successfully
# Authenticated using device code flow.

# %%
# 2. Lê o shapefile e converte para GeoJSON (deve estar em EPSG:4326)
shapefile_path = "/content/drive/MyDrive/Dissertacao/areas/fazenda_OuroFino2/AOI_ourofino.shp" # Altere o arquivo com base no caminho do seu arquivo shp - no SRC WGS 84
aoi = gpd.read_file(shapefile_path).to_crs(epsg=4326)
aoi_geojson = mapping(aoi.geometry.union_all())

# %%
# 3. Parâmetros
start_date = datetime(2018, 5, 1) # Data de início da sua série
end_date = datetime(2025, 5, 13) # Data de término da série
max_cloud = 35 # Defina a cobertura de nuvens máxima da imagem
scale = 10  # Resolução em m²/pixel

# %% [markdown]
# ##Funções Principais

# %%
# 4. Função para calcular índices - Altere aqui com base nos índices que deseja calcular
def calcular_indices(datacube):
    ndvi = (datacube.band("B08") - datacube.band("B04")) / (datacube.band("B08") + datacube.band("B04"))
    ndre = (datacube.band("B08") - datacube.band("B05")) / (datacube.band("B08") + datacube.band("B05"))
    ndwi1 = (datacube.band("B11") - datacube.band("B08")) / (datacube.band("B11") + datacube.band("B08"))
    ndwi2 = (datacube.band("B12") - datacube.band("B08")) / (datacube.band("B12") + datacube.band("B08"))
    lnc = ((datacube.band("B08") - datacube.band("B05")) / (datacube.band("B08") + datacube.band("B05"))) * 4.060 + 0.43
    mcari = ((datacube.band("B05") - datacube.band("B04") * 0.2 - datacube.band("B03")) * datacube.band("B05")) / datacube.band("B04")
    mcari1 = ((datacube.band("B08") - datacube.band("B04")) * 2.5 - (datacube.band("B08") - datacube.band("B03")) * 1.3) * 1.2
    gndvi = (datacube.band("B08") - datacube.band("B03")) / (datacube.band("B08") + datacube.band("B03"))
    gosavi = 1.16 * ((datacube.band("B08") - datacube.band("B03")) / (datacube.band("B08") + datacube.band("B03") + 0.16))
    return {
        "NDVI": ndvi,
        "NDRE": ndre,
        "NDWI1": ndwi1,
        "NDWI2": ndwi2,
        "LNC": lnc,
        "MCARI": mcari,
        "MCARI1": mcari1,
        "GNDVI": gndvi,
        "GOSAVI": gosavi
    }

# %%
# 5. Loop mensal - Define o intervalo para o download das imagens, no código atual é baixada 1 imagem por mês, selecionando a melhor imagem com base na cobertura de imagens total
current = start_date
while current < end_date:
    start_str = current.strftime("%Y-%m-%d")
    year_month = current.strftime("%Y-%m")
    print(f"\n🔄 Processando mês: {year_month}...")

    try:
        datacube = conn.load_collection(
            "SENTINEL2_L2A",
            spatial_extent=aoi_geojson,
            temporal_extent=[start_str, (current + timedelta(days=31)).replace(day=1).strftime("%Y-%m-%d")],
            bands=["B03", "B04", "B05", "B08", "B11", "B12"],
            max_cloud_cover=max_cloud
        )
    except:
        print("⚠️ L2A não disponível. Usando L1C.")
        datacube = conn.load_collection(
            "SENTINEL2_L1C",
            spatial_extent=aoi_geojson,
            temporal_extent=[start_str, (current + timedelta(days=31)).replace(day=1).strftime("%Y-%m-%d")],
            bands=["B03", "B04", "B05", "B08", "B11", "B12"],
            max_cloud_cover=max_cloud
        )

    datacube = datacube.reduce_dimension(dimension="t", reducer="mean")
    indices = calcular_indices(datacube)

    for nome, banda in indices.items():
        folder = f"/content/drive/MyDrive/Dissertacao/indices/ouro_fino/openEO/{nome}"
        os.makedirs(folder, exist_ok=True)

        # Nome final do arquivo com índice e data
        filename = f"{nome}_{year_month}.tif"
        filepath = os.path.join(folder, filename)

        # Verifica se o arquivo já existe
        if os.path.exists(filepath):
            print(f"⏭️ {filename} já existe. Pulando...")
            continue

        print(f"📥 Iniciando download de {filename}...")

        try:
            result = banda.save_result(format="GTiff")
            job = result.create_job(title=filename)
            job.start_and_wait()

            # Lista arquivos antes do download
            arquivos_antes = set(os.listdir(folder))

            # Faz o download
            job.download_results(target=folder)

            # Lista arquivos após o download
            arquivos_depois = set(os.listdir(folder))
            novos_arquivos = arquivos_depois - arquivos_antes

            novos_tifs = [f for f in novos_arquivos if f.endswith(".tif")]

            if novos_tifs:
                downloaded_path = os.path.join(folder, novos_tifs[0])
                shutil.move(downloaded_path, filepath)
                print(f"✅ {filename} salvo com sucesso.")
            else:
                print(f"⚠️ Nenhum arquivo .tif novo encontrado após download para {nome} em {year_month}.")

        except Exception as e:
            print(f"❌ Erro ao processar {filename}: {e}")

    current = (current + timedelta(days=31)).replace(day=1)

print("\n✅ Todos os meses foram processados com sucesso!")
# Out:
# 🔄 Processando mês: 2018-05...
# ⏭️ NDVI_2018-05.tif já existe. Pulando...
# ⏭️ NDRE_2018-05.tif já existe. Pulando...
# ⏭️ NDWI1_2018-05.tif já existe. Pulando...
# ⏭️ NDWI2_2018-05.tif já existe. Pulando...
# ⏭️ LNC_2018-05.tif já existe. Pulando...
# ⏭️ MCARI_2018-05.tif já existe. Pulando...
# ⏭️ MCARI1_2018-05.tif já existe. Pulando...
# ⏭️ GNDVI_2018-05.tif já existe. Pulando...
# ⏭️ GOSAVI_2018-05.tif já existe. Pulando...
#
# 🔄 Processando mês: 2018-06...
# ⏭️ NDVI_2018-06.tif já existe. Pulando...
# ⏭️ NDRE_2018-06.tif já existe. Pulando...
# ⏭️ NDWI1_2018-06.tif já existe. Pulando...
# ⏭️ NDWI2_2018-06.tif já existe. Pulando...
# ⏭️ LNC_2018-06.tif já existe. Pulando...
# ⏭️ MCARI_2018-06.tif já existe. Pulando...
# ⏭️ MCARI1_2018-06.tif já existe. Pulando...
# ⏭️ GNDVI_2018-06.tif já existe. Pulando...
# ⏭️ GOSAVI_2018-06.tif já existe. Pulando...
#
# 🔄 Processando mês: 2018-07...
# ⏭️ NDVI_2018-07.tif já existe. Pulando...
# ⏭️ NDRE_2018-07.tif já existe. Pulando...
# ⏭️ NDWI1_2018-07.tif já existe. Pulando...
# ⏭️ NDWI2_2018-07.tif já existe. Pulando...
# ⏭️ LNC_2018-07.tif já existe. Pulando...
# ⏭️ MCARI_2018-07.tif já existe. Pulando...
# ⏭️ MCARI1_2018-07.tif já existe. Pulando...
# ⏭️ GNDVI_2018-07.tif já existe. Pulando...
# ⏭️ GOSAVI_2018-07.tif já existe. Pulando...
#
# 🔄 Processando mês: 2018-08...
# ⏭️ NDVI_2018-08.tif já existe. Pulando...
# ⏭️ NDRE_2018-08.tif já existe. Pulando...
# ⏭️ NDWI1_2018-08.tif já existe. Pulando...
# ⏭️ NDWI2_2018-08.tif já existe. Pulando...
# ⏭️ LNC_2018-08.tif já existe. Pulando...
# ⏭️ MCARI_2018-08.tif já existe. Pulando...
# ⏭️ MCARI1_2018-08.tif já existe. Pulando...
# ⏭️ GNDVI_2018-08.tif já existe. Pulando...
# ⏭️ GOSAVI_2018-08.tif já existe. Pulando...
#
# 🔄 Processando mês: 2018-09...
# ⏭️ NDVI_2018-09.tif já existe. Pulando...
# ⏭️ NDRE_2018-09.tif já existe. Pulando...
# ⏭️ NDWI1_2018-09.tif já existe. Pulando...
# ⏭️ NDWI2_2018-09.tif já existe. Pulando...
# ⏭️ LNC_2018-09.tif já existe. Pulando...
# ⏭️ MCARI_2018-09.tif já existe. Pulando...
# ⏭️ MCARI1_2018-09.tif já existe. Pulando...
# ⏭️ GNDVI_2018-09.tif já existe. Pulando...
# ⏭️ GOSAVI_2018-09.tif já existe. Pulando...
#
# 🔄 Processando mês: 2018-10...
# 📥 Iniciando download de NDVI_2018-10.tif...
# 0:00:00 Job 'j-25051613295449c78d75b65668de5dee': send 'start'
# 0:00:13 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:00:18 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:00:25 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:00:33 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:00:43 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:00:55 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:01:11 Job 'j-25051613295449c78d75b65668de5dee': running (progress N/A)
# 0:01:30 Job 'j-25051613295449c78d75b65668de5dee': error (progress N/A)
# Your batch job 'j-25051613295449c78d75b65668de5dee' failed. Error logs:
# [{'id': '[1747402231448, 826717]', 'time': '2025-05-16T13:30:31.448Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25051613295449c78d75b65668de5dee" and returned 0 results.'}, {'id': '[1747402232600, 284494]', 'time': '2025-05-16T13:30:32.600Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25051613295449c78d75b65668de5dee" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-25051613295449c78d75b65668de5dee').logs()`.
# ❌ Erro ao processar NDVI_2018-10.tif: Batch job 'j-25051613295449c78d75b65668de5dee' didn't finish successfully. Status: error (after 0:01:31).
# 📥 Iniciando download de NDRE_2018-10.tif...
# 0:00:00 Job 'j-250516133126412486e7771690488dc9': send 'start'
# 0:00:14 Job 'j-250516133126412486e7771690488dc9': created (progress 0%)
# 0:00:19 Job 'j-250516133126412486e7771690488dc9': created (progress 0%)
# 0:00:25 Job 'j-250516133126412486e7771690488dc9': created (progress 0%)
# 0:00:33 Job 'j-250516133126412486e7771690488dc9': created (progress 0%)
# 0:00:43 Job 'j-250516133126412486e7771690488dc9': error (progress N/A)
# Your batch job 'j-250516133126412486e7771690488dc9' failed. Error logs:
# [{'id': '[1747402320395, 37855]', 'time': '2025-05-16T13:32:00.395Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-250516133126412486e7771690488dc9" and returned 0 results.'}, {'id': '[1747402321566, 871550]', 'time': '2025-05-16T13:32:01.566Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-250516133126412486e7771690488dc9" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-250516133126412486e7771690488dc9').logs()`.
# ❌ Erro ao processar NDRE_2018-10.tif: Batch job 'j-250516133126412486e7771690488dc9' didn't finish successfully. Status: error (after 0:00:44).
# 📥 Iniciando download de NDWI1_2018-10.tif...
# 0:00:00 Job 'j-2505161332114fbe95897fc228c586c0': send 'start'
# 0:00:13 Job 'j-2505161332114fbe95897fc228c586c0': created (progress 0%)
# 0:00:19 Job 'j-2505161332114fbe95897fc228c586c0': created (progress 0%)
# 0:00:25 Job 'j-2505161332114fbe95897fc228c586c0': created (progress 0%)
# 0:00:33 Job 'j-2505161332114fbe95897fc228c586c0': created (progress 0%)
# 0:00:43 Job 'j-2505161332114fbe95897fc228c586c0': created (progress 0%)
# 0:00:56 Job 'j-2505161332114fbe95897fc228c586c0': error (progress N/A)
# Your batch job 'j-2505161332114fbe95897fc228c586c0' failed. Error logs:
# [{'id': '[1747402366619, 856319]', 'time': '2025-05-16T13:32:46.619Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161332114fbe95897fc228c586c0" and returned 0 results.'}, {'id': '[1747402367629, 765033]', 'time': '2025-05-16T13:32:47.629Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161332114fbe95897fc228c586c0" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2505161332114fbe95897fc228c586c0').logs()`.
# ❌ Erro ao processar NDWI1_2018-10.tif: Batch job 'j-2505161332114fbe95897fc228c586c0' didn't finish successfully. Status: error (after 0:00:56).
# 📥 Iniciando download de NDWI2_2018-10.tif...
# 0:00:00 Job 'j-25051613330842d79a4831f081ca785d': send 'start'
# 0:00:13 Job 'j-25051613330842d79a4831f081ca785d': created (progress 0%)
# 0:00:19 Job 'j-25051613330842d79a4831f081ca785d': created (progress 0%)
# 0:00:25 Job 'j-25051613330842d79a4831f081ca785d': created (progress 0%)
# 0:00:33 Job 'j-25051613330842d79a4831f081ca785d': created (progress 0%)
z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161336194c9d92b4477bd4c3b1f9" and returned 0 results.'}, {'id': '[1747402614004, 426266]', 'time': '2025-05-16T13:36:54.004Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161336194c9d92b4477bd4c3b1f9" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2505161336194c9d92b4477bd4c3b1f9').logs()`.
# ❌ Erro ao processar MCARI_2018-10.tif: Batch job 'j-2505161336194c9d92b4477bd4c3b1f9' didn't finish successfully. Status: error (after 0:00:56).
# 📥 Iniciando download de MCARI1_2018-10.tif...
# 0:00:00 Job 'j-25051613371644ce82cd7807d6d6c0b5': send 'start'
# 0:00:13 Job 'j-25051613371644ce82cd7807d6d6c0b5': created (progress 0%)
# 0:00:18 Job 'j-25051613371644ce82cd7807d6d6c0b5': created (progress 0%)
# 0:00:25 Job 'j-25051613371644ce82cd7807d6d6c0b5': created (progress 0%)
# 0:00:33 Job 'j-25051613371644ce82cd7807d6d6c0b5': created (progress 0%)
# 0:00:43 Job 'j-25051613371644ce82cd7807d6d6c0b5': created (progress 0%)
# 0:00:55 Job 'j-25051613371644ce82cd7807d6d6c0b5': running (progress N/A)
# 0:01:11 Job 'j-25051613371644ce82cd7807d6d6c0b5': running (progress N/A)
# 0:01:30 Job 'j-25051613371644ce82cd7807d6d6c0b5': running (progress N/A)
# 0:01:54 Job 'j-25051613371644ce82cd7807d6d6c0b5': error (progress N/A)
# Your batch job 'j-25051613371644ce82cd7807d6d6c0b5' failed. Error logs:
# [{'id': '[1747402681443, 311924]', 'time': '2025-05-16T13:38:01.443Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25051613371644ce82cd7807d6d6c0b5" and returned 0 results.'}, {'id': '[1747402682641, 945638]', 'time': '2025-05-16T13:38:02.641Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25051613371644ce82cd7807d6d6c0b5" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-25051613371644ce82cd7807d6d6c0b5').logs()`.
# ❌ Erro ao processar MCARI1_2018-10.tif: Batch job 'j-25051613371644ce82cd7807d6d6c0b5' didn't finish successfully. Status: error (after 0:01:55).
# 📥 Iniciando download de GNDVI_2018-10.tif...
# 0:00:00 Job 'j-2505161339114bddaee221d51f4941af': send 'start'
# 0:00:13 Job 'j-2505161339114bddaee221d51f4941af': created (progress 0%)
# 0:00:18 Job 'j-2505161339114bddaee221d51f4941af': created (progress 0%)
# 0:00:24 Job 'j-2505161339114bddaee221d51f4941af': created (progress 0%)
# 0:00:33 Job 'j-2505161339114bddaee221d51f4941af': created (progress 0%)
# 0:00:43 Job 'j-2505161339114bddaee221d51f4941af': created (progress 0%)
# 0:00:55 Job 'j-2505161339114bddaee221d51f4941af': error (progress N/A)
# Your batch job 'j-2505161339114bddaee221d51f4941af' failed. Error logs:
# [{'id': '[1747402790271, 734335]', 'time': '2025-05-16T13:39:50.271Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161339114bddaee221d51f4941af" and returned 0 results.'}, {'id': '[1747402791441, 980981]', 'time': '2025-05-16T13:39:51.441Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161339114bddaee221d51f4941af" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2505161339114bddaee221d51f4941af').logs()`.
# ❌ Erro ao processar GNDVI_2018-10.tif: Batch job 'j-2505161339114bddaee221d51f4941af' didn't finish successfully. Status: error (after 0:00:56).
# 📥 Iniciando download de GOSAVI_2018-10.tif...
# 0:00:00 Job 'j-25051613400843709386ade49c42fa92': send 'start'
# 0:00:14 Job 'j-25051613400843709386ade49c42fa92': created (progress 0%)
# 0:00:19 Job 'j-25051613400843709386ade49c42fa92': created (progress 0%)
# 0:00:25 Job 'j-25051613400843709386ade49c42fa92': created (progress 0%)
# 0:00:34 Job 'j-25051613400843709386ade49c42fa92': created (progress 0%)
# 0:00:44 Job 'j-25051613400843709386ade49c42fa92': created (progress 0%)
# 0:00:56 Job 'j-25051613400843709386ade49c42fa92': created (progress 0%)
# 0:01:12 Job 'j-25051613400843709386ade49c42fa92': error (progress N/A)
# Your batch job 'j-25051613400843709386ade49c42fa92' failed. Error logs:
# [{'id': '[1747402851064, 796746]', 'time': '2025-05-16T13:40:51.064Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25051613400843709386ade49c42fa92" and returned 0 results.'}, {'id': '[1747402852585, 351196]', 'time': '2025-05-16T13:40:52.585Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25051613400843709386ade49c42fa92" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-25051613400843709386ade49c42fa92').logs()`.
# ❌ Erro ao processar GOSAVI_2018-10.tif: Batch job 'j-25051613400843709386ade49c42fa92' didn't finish successfully. Status: error (after 0:01:12).
#
# 🔄 Processando mês: 2018-11...
# 📥 Iniciando download de NDVI_2018-11.tif...
# 0:00:00 Job 'j-25051613412147fdbb3bd6ac1010d101': send 'start'
# 0:00:13 Job 'j-25051613412147fdbb3bd6ac1010d101': created (progress 0%)
# 0:00:18 Job 'j-25051613412147fdbb3bd6ac1010d101': created (progress 0%)
# 0:00:25 Job 'j-25051613412147fdbb3bd6ac1010d101': created (progress 0%)
# 0:00:33 Job 'j-25051613412147fdbb3bd6ac1010d101': created (progress 0%)
# 0:00:43 Job 'j-25051613412147fdbb3bd6ac1010d101': created (progress 0%)
# 0:00:55 Job 'j-25051613412147fdbb3bd6ac1010d101': running (progress N/A)
# 0:01:11 Job 'j-25051613412147fdbb3bd6ac1010d101': running (progress N/A)
# 0:01:30 Job 'j-25051613412147fdbb3bd6ac1010d101': running (progress N/A)
# 0:01:54 Job 'j-25051613412147fdbb3bd6ac1010d101': finished (progress 100%)
# <ipython-input-10-60f5f3c9b0f6>:53: UserDeprecationWarning: Call to deprecated method download_results. (Instead use `BatchJob.get_results` and the more flexible download functionality of `JobResults`) -- Deprecated since version 0.4.10.
#   job.download_results(target=folder)
# /usr/local/lib/python3.11/dist-packages/openeo/rest/job.py:174: UserDeprecationWarning: Call to deprecated method get_result. (Use `BatchJob.get_results` instead.) -- Deprecated since version 0.4.10.
#   return self.get_result().download_files(target)
# /usr/local/lib/python3.11/dist-packages/openeo/rest/job.py:178: UserDeprecationWarning: Call to deprecated class _Result. (Use `JobResults` instead) -- Deprecated since version 0.4.10.
#   return _Result(self)
# ✅ NDVI_2018-11.tif salvo com sucesso.
# 📥 Iniciando download
2018-11.tif salvo com sucesso.
# 📥 Iniciando download de MCARI_2018-11.tif...
# 0:00:00 Job 'j-25051613511447eaa8b935f95473a4e5': send 'start'
# 0:00:13 Job 'j-25051613511447eaa8b935f95473a4e5': created (progress 0%)
# 0:00:18 Job 'j-25051613511447eaa8b935f95473a4e5': created (progress 0%)
# 0:00:25 Job 'j-25051613511447eaa8b935f95473a4e5': created (progress 0%)
# 0:00:33 Job 'j-25051613511447eaa8b935f95473a4e5': created (progress 0%)
# 0:00:43 Job 'j-25051613511447eaa8b935f95473a4e5': created (progress 0%)
# 0:00:55 Job 'j-25051613511447eaa8b935f95473a4e5': running (progress N/A)
# 0:01:11 Job 'j-25051613511447eaa8b935f95473a4e5': running (progress N/A)
# 0:01:30 Job 'j-25051613511447eaa8b935f95473a4e5': running (progress N/A)
# 0:01:54 Job 'j-25051613511447eaa8b935f95473a4e5': running (progress N/A)
# 0:02:25 Job 'j-25051613511447eaa8b935f95473a4e5': finished (progress 100%)
# ✅ MCARI_2018-11.tif salvo com sucesso.
# 📥 Iniciando download de MCARI1_2018-11.tif...
# 0:00:00 Job 'j-2505161353414baf9f050f2bd080c5b8': send 'start'
# 0:00:14 Job 'j-2505161353414baf9f050f2bd080c5b8': created (progress 0%)
# 0:00:19 Job 'j-2505161353414baf9f050f2bd080c5b8': created (progress 0%)
# 0:00:26 Job 'j-2505161353414baf9f050f2bd080c5b8': running (progress N/A)
# 0:00:34 Job 'j-2505161353414baf9f050f2bd080c5b8': running (progress N/A)
# 0:00:44 Job 'j-2505161353414baf9f050f2bd080c5b8': running (progress N/A)
# 0:00:56 Job 'j-2505161353414baf9f050f2bd080c5b8': running (progress N/A)
# 0:01:12 Job 'j-2505161353414baf9f050f2bd080c5b8': running (progress N/A)
# 0:01:31 Job 'j-2505161353414baf9f050f2bd080c5b8': finished (progress 100%)
# ✅ MCARI1_2018-11.tif salvo com sucesso.
# 📥 Iniciando download de GNDVI_2018-11.tif...
# 0:00:00 Job 'j-25051613551540d5a162d629f15ae297': send 'start'
# 0:00:13 Job 'j-25051613551540d5a162d629f15ae297': created (progress 0%)
# 0:00:19 Job 'j-25051613551540d5a162d629f15ae297': created (progress 0%)
# 0:00:25 Job 'j-25051613551540d5a162d629f15ae297': created (progress 0%)
# 0:00:33 Job 'j-25051613551540d5a162d629f15ae297': created (progress 0%)
# 0:00:43 Job 'j-25051613551540d5a162d629f15ae297': created (progress 0%)
# 0:00:56 Job 'j-25051613551540d5a162d629f15ae297': running (progress N/A)
# 0:01:11 Job 'j-25051613551540d5a162d629f15ae297': running (progress N/A)
# 0:01:31 Job 'j-25051613551540d5a162d629f15ae297': running (progress N/A)
# 0:01:55 Job 'j-25051613551540d5a162d629f15ae297': finished (progress 100%)
# ✅ GNDVI_2018-11.tif salvo com sucesso.
# 📥 Iniciando download de GOSAVI_2018-11.tif...
# 0:00:00 Job 'j-25051613571347fd9ef55ed6d90d762a': send 'start'
# 0:00:13 Job 'j-25051613571347fd9ef55ed6d90d762a': created (progress 0%)
# 0:00:18 Job 'j-25051613571347fd9ef55ed6d90d762a': created (progress 0%)
# 0:00:25 Job 'j-25051613571347fd9ef55ed6d90d762a': created (progress 0%)
# 0:00:33 Job 'j-25051613571347fd9ef55ed6d90d762a': created (progress 0%)
# 0:00:43 Job 'j-25051613571347fd9ef55ed6d90d762a': created (progress 0%)
# 0:00:55 Job 'j-25051613571347fd9ef55ed6d90d762a': running (progress N/A)
# 0:01:11 Job 'j-25051613571347fd9ef55ed6d90d762a': running (progress N/A)
# 0:01:30 Job 'j-25051613571347fd9ef55ed6d90d762a': running (progress N/A)
# 0:01:54 Job 'j-25051613571347fd9ef55ed6d90d762a': running (progress N/A)
# 0:02:24 Job 'j-25051613571347fd9ef55ed6d90d762a': finished (progress 100%)
# ✅ GOSAVI_2018-11.tif salvo com sucesso.
#
# 🔄 Processando mês: 2018-12...
# ⏭️ NDVI_2018-12.tif já existe. Pulando...
# ⏭️ NDRE_2018-12.tif já existe. Pulando...
# ⏭️ NDWI1_2018-12.tif já existe. Pulando...
# ⏭️ NDWI2_2018-12.tif já existe. Pulando...
# ⏭️ LNC_2018-12.tif já existe. Pulando...
# ⏭️ MCARI_2018-12.tif já existe. Pulando...
# ⏭️ MCARI1_2018-12.tif já existe. Pulando...
# ⏭️ GNDVI_2018-12.tif já existe. Pulando...
# ⏭️ GOSAVI_2018-12.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-01...
# ⏭️ NDVI_2019-01.tif já existe. Pulando...
# ⏭️ NDRE_2019-01.tif já existe. Pulando...
# ⏭️ NDWI1_2019-01.tif já existe. Pulando...
# ⏭️ NDWI2_2019-01.tif já existe. Pulando...
# ⏭️ LNC_2019-01.tif já existe. Pulando...
# ⏭️ MCARI_2019-01.tif já existe. Pulando...
# ⏭️ MCARI1_2019-01.tif já existe. Pulando...
# ⏭️ GNDVI_2019-01.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-01.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-02...
# ⏭️ NDVI_2019-02.tif já existe. Pulando...
# ⏭️ NDRE_2019-02.tif já existe. Pulando...
# ⏭️ NDWI1_2019-02.tif já existe. Pulando...
# ⏭️ NDWI2_2019-02.tif já existe. Pulando...
# ⏭️ LNC_2019-02.tif já existe. Pulando...
# ⏭️ MCARI_2019-02.tif já existe. Pulando...
# ⏭️ MCARI1_2019-02.tif já existe. Pulando...
# ⏭️ GNDVI_2019-02.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-02.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-03...
# ⏭️ NDVI_2019-03.tif já existe. Pulando...
# ⏭️ NDRE_2019-03.tif já existe. Pulando...
# ⏭️ NDWI1_2019-03.tif já existe. Pulando...
# ⏭️ NDWI2_2019-03.tif já existe. Pulando...
# ⏭️ LNC_2019-03.tif já existe. Pulando...
# ⏭️ MCARI_2019-03.tif já existe. Pulando...
# ⏭️ MCARI1_2019-03.tif já existe. Pulando...
# ⏭️ GNDVI_2019-03.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-03.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-04...
# ⏭️ NDVI_2019-04.tif já existe. Pulando...
# ⏭️ NDRE_2019-04.tif já existe. Pulando...
# ⏭️ NDWI1_2019-04.tif já existe. Pulando...
# ⏭️ NDWI2_2019-04.tif já existe. Pulando...
# ⏭️ LNC_2019-04.tif já existe. Pulando...
# ⏭️ MCARI_2019-04.tif já existe. Pulando...
# ⏭️ MCARI1_2019-04.tif já existe. Pulando...
# ⏭️ GNDVI_2019-04.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-04.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-05...
# ⏭️ NDVI_2019-05.tif já existe. Pulando...
# ⏭️ NDRE_2019-05.tif já existe. Pulando...
# ⏭️ NDWI1_2019-05.tif já existe. Pulando...
# ⏭️ NDWI2_2019-05.tif já existe. Pulando...
# ⏭️ LNC_2019-05.tif já existe. Pulando...
# ⏭️ MCARI_2019-05.tif já existe. Pulando...
# ⏭️ MCARI1_2019-05.tif já existe. Pulando...
# ⏭️ GNDVI_2019-05.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-05.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-06...
# ⏭️ NDVI_2019-06.tif já existe. Pulando...
# ⏭️ NDRE_2019-06.tif já existe. Pulando...
# ⏭️ NDWI1_2019-06.tif já existe. Pulando...
# ⏭️ NDWI2_2019-06.tif já existe. Pulando...
# ⏭️ LNC_2019-06.tif já existe. Pulando...
# ⏭️ MCARI_2019-06.tif já existe. Pulando...
# ⏭️ MCARI1_2019-06.tif já existe. Pulando...
# ⏭️ GNDVI_2019-06.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-06.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-07...
# ⏭️ NDVI_2019-07.tif já existe. Pulando...
# ⏭️ NDRE_2019-07.tif já existe. Pulando...
# ⏭️ NDWI1_2019-07.tif já existe. Pulando...
# ⏭️ NDWI2_2019-07.tif já existe. Pulando...
# ⏭️ LNC_2019-07.tif já existe. Pulando...
# ⏭️ MCARI_2019-07.tif já existe. Pulando...
# ⏭️ MCARI1_2019-07.tif já existe. Pulando...
# ⏭️ GNDVI_2019-07.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-07.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-08...
# ⏭️ NDVI_2019-08.tif já existe. Pulando...
# ⏭️ NDRE_2019-08.tif já existe. Pulando...
# ⏭️ NDWI1_2019-08.tif já existe. Pulando...
# ⏭️ NDWI2_2019-08.tif já existe. Pulando...
# ⏭️ LNC_2019-08.tif já existe. Pulando...
# ⏭️ MCARI_2019-08.tif já existe. Pulando...
# ⏭️ MCARI1_2019-08.tif já existe. Pulando...
# ⏭️ GNDVI_2019-08.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-08.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-09...
# ⏭️ NDVI_2019-09.tif já existe. Pulando...
# ⏭️ NDRE_2019-09.tif já existe. Pulando...
# ⏭️ NDWI1_2019-09.tif já existe. Pulando...
# ⏭️ NDWI2_2019-09.tif já existe. Pulando...
# ⏭️ LNC_2019-09.tif já existe. Pulando...
# ⏭️ MCARI_2019-09.tif já existe. Pulando...
# ⏭️ MCARI1_2019-09.tif já existe. Pulando...
# ⏭️ GNDVI_2019-09.tif já existe. Pulando...
# ⏭️ GOSAVI_2019-09.tif já existe. Pulando...
#
# 🔄 Processando mês: 2019-10...
# ⏭️ NDVI_2019-10.tif já existe. Pulando...
# ⏭️ NDRE_2019-10.tif já existe. Pulando...
# ⏭️ NDWI1_2019-10.tif já existe. Pulando...
# ⏭️ NDWI2_2019-10.tif já existe. Pulando...
# ⏭️ LNC_2019-10.tif já existe. Pulando...
# ⏭️ MCARI_2019-10.tif já existe. Pulando...
# ⏭️ MCARI1_2019-10.tif já existe. Pulando...
# ⏭️ GNDVI_2019-10.tif já existe. Pulando...
# ⏭️ GOSAVI_2019
2019-12.tif salvo com sucesso.
# 📥 Iniciando download de MCARI1_2019-12.tif...
# 0:00:00 Job 'j-2505161410354b7aa623d9b699f7add4': send 'start'
# 0:00:13 Job 'j-2505161410354b7aa623d9b699f7add4': created (progress 0%)
# 0:00:18 Job 'j-2505161410354b7aa623d9b699f7add4': created (progress 0%)
# 0:00:25 Job 'j-2505161410354b7aa623d9b699f7add4': created (progress 0%)
# 0:00:33 Job 'j-2505161410354b7aa623d9b699f7add4': running (progress N/A)
# 0:00:43 Job 'j-2505161410354b7aa623d9b699f7add4': running (progress N/A)
# 0:00:56 Job 'j-2505161410354b7aa623d9b699f7add4': running (progress N/A)
# 0:01:11 Job 'j-2505161410354b7aa623d9b699f7add4': running (progress N/A)
# 0:01:31 Job 'j-2505161410354b7aa623d9b699f7add4': running (progress N/A)
# 0:01:55 Job 'j-2505161410354b7aa623d9b699f7add4': finished (progress 100%)
# ✅ MCARI1_2019-12.tif salvo com sucesso.
# 📥 Iniciando download de GNDVI_2019-12.tif...
# 0:00:00 Job 'j-250516141232462383fb4e9a375d483c': send 'start'
# 0:00:13 Job 'j-250516141232462383fb4e9a375d483c': created (progress 0%)
# 0:00:19 Job 'j-250516141232462383fb4e9a375d483c': created (progress 0%)
# 0:00:25 Job 'j-250516141232462383fb4e9a375d483c': created (progress 0%)
# 0:00:33 Job 'j-250516141232462383fb4e9a375d483c': created (progress 0%)
# 0:00:43 Job 'j-250516141232462383fb4e9a375d483c': running (progress N/A)
# 0:00:56 Job 'j-250516141232462383fb4e9a375d483c': running (progress N/A)
# 0:01:11 Job 'j-250516141232462383fb4e9a375d483c': running (progress N/A)
# 0:01:31 Job 'j-250516141232462383fb4e9a375d483c': running (progress N/A)
# 0:01:55 Job 'j-250516141232462383fb4e9a375d483c': finished (progress 100%)
# ✅ GNDVI_2019-12.tif salvo com sucesso.
# 📥 Iniciando download de GOSAVI_2019-12.tif...
# 0:00:00 Job 'j-25051614143047ac95d3dd169baa59c2': send 'start'
# 0:00:13 Job 'j-25051614143047ac95d3dd169baa59c2': created (progress 0%)
# 0:00:18 Job 'j-25051614143047ac95d3dd169baa59c2': created (progress 0%)
# 0:00:25 Job 'j-25051614143047ac95d3dd169baa59c2': created (progress 0%)
# 0:00:33 Job 'j-25051614143047ac95d3dd169baa59c2': created (progress 0%)
# 0:00:43 Job 'j-25051614143047ac95d3dd169baa59c2': queued (progress 0%)
# 0:00:56 Job 'j-25051614143047ac95d3dd169baa59c2': queued (progress 0%)
# 0:01:12 Job 'j-25051614143047ac95d3dd169baa59c2': queued (progress 0%)
# 0:01:31 Job 'j-25051614143047ac95d3dd169baa59c2': queued (progress 0%)
# 0:01:55 Job 'j-25051614143047ac95d3dd169baa59c2': running (progress N/A)
# 0:02:25 Job 'j-25051614143047ac95d3dd169baa59c2': running (progress N/A)
# 0:03:03 Job 'j-25051614143047ac95d3dd169baa59c2': finished (progress 100%)
# ✅ GOSAVI_2019-12.tif salvo com sucesso.
#
# 🔄 Processando mês: 2020-01...
# 📥 Iniciando download de NDVI_2020-01.tif...
# 0:00:00 Job 'j-2505161417364211941e82a6961e1134': send 'start'
# 0:00:13 Job 'j-2505161417364211941e82a6961e1134': created (progress 0%)
# 0:00:18 Job 'j-2505161417364211941e82a6961e1134': created (progress 0%)
# 0:00:25 Job 'j-2505161417364211941e82a6961e1134': created (progress 0%)
# 0:00:33 Job 'j-2505161417364211941e82a6961e1134': queued (progress 0%)
# 0
z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-250516142815452faac638eb77ef6ddc" and returned 0 results.'}, {'id': '[1747405921568, 109075]', 'time': '2025-05-16T14:32:01.568Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-250516142815452faac638eb77ef6ddc" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-250516142815452faac638eb77ef6ddc').logs()`.
# ❌ Erro ao processar NDWI1_2020-01.tif: Batch job 'j-250516142815452faac638eb77ef6ddc' didn't finish successfully. Status: error (after 0:04:48).
# 📥 Iniciando download de NDWI2_2020-01.tif...
# 0:00:00 Job 'j-2505161433044fe28295df265f1d1e64': send 'start'
# 0:00:13 Job 'j-2505161433044fe28295df265f1d1e64': queued (progress 0%)
# 0:00:18 Job 'j-2505161433044fe28295df265f1d1e64': queued (progress 0%)
# 0:00:25 Job 'j-2505161433044fe28295df265f1d1e64': queued (progress 0%)
# 0:00:33 Job 'j-2505161433044fe28295df265f1d1e64': queued (progress 0%)
# 0:00:43 Job 'j-2505161433044fe28295df265f1d1e64': queued (progress 0%)
# 0:00:56 Job 'j-2505161433044fe28295df265f1d1e64': queued (progress 0%)
# 0:01:11 Job 'j-2505161433044fe28295df265f1d1e64': error (progress N/A)
# Your batch job 'j-2505161433044fe28295df265f1d1e64' failed. Error logs:
# [{'id': '[1747406034634, 686182]', 'time': '2025-05-16T14:33:54.634Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161433044fe28295df265f1d1e64" and returned 0 results.'}, {'id': '[1747406037568, 716929]', 'time': '2025-05-16T14:33:57.568Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161433044fe28295df265f1d1e64" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2505161433044fe28295df265f1d1e64').logs()`.
# ❌ Erro ao processar NDWI2_2020-01.tif: Batch job 'j-2505161433044fe28295df265f1d1e64' didn't finish successfully. Status: error (after 0:01:11).
# 📥 Iniciando download de LNC_2020-01.tif...
# 0:00:00 Job 'j-2505161434174fd5af4290dbf48dd50f': send 'start'
# 0:00:13 Job 'j-2505161434174fd5af4290dbf48dd50f': created (progress 0%)
# 0:00:18 Job 'j-2505161434174fd5af4290dbf48dd50f': created (progress 0%)
# 0:00:24 Job 'j-2505161434174fd5af4290dbf48dd50f': created (progress 0%)
# 0:00:32 Job 'j-2505161434174fd5af4290dbf48dd50f': created (progress 0%)
# 0:00:43 Job 'j-2505161434174fd5af4290dbf48dd50f': created (progress 0%)
# 0:00:55 Job 'j-2505161434174fd5af4290dbf48dd50f': running (progress N/A)
# 0:01:11 Job 'j-2505161434174fd5af4290dbf48dd50f': running (progress N/A)
# 0:01:30 Job 'j-2505161434174fd5af4290dbf48dd50f': running (progress N/A)
# 0:01:54 Job 'j-2505161434174fd5af4290dbf48dd50f': error (progress N/A)
# Your batch job 'j-2505161434174fd5af4290dbf48dd50f' failed. Error logs:
# [{'id': '[1747406105232, 499399]', 'time': '2025-05-16T14:35:05.232Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161434174fd5af4290dbf48dd50f" and returned 0 results.'}, {'id': '[1747406106997, 860187]', 'time': '2025-05-16T14:35:06.997Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2505161434174fd5af4290dbf48dd50f" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2505161434174fd5af4290dbf48dd50f').logs()`.
# ❌ Erro ao processar LNC_2020-01.tif: Batch job 'j-2505161434174fd5af4290dbf48dd50f' didn't finish successfully. Status: error (after 0:01:54).
# 📥 Iniciando download de MCARI_2020-01.tif...
# 0:00:00 Job 'j-25051614361248058a4e39d145f1043b': send 'start'
# 0:00:13 Job 'j-25051614361248058a4e39d145f1043b': created (progress 0%)
# ...
# 0:00:15 Job 'j-2505161901404f9ab4f9996fb258ec43': created (progress 0%)
# 0:00:20 Job 'j-2505161901404f9ab4f9996fb258ec43': created (progress 0%)
# 0:00:26 Job 'j-2505161901404f9ab4f9996fb258ec43': created (progress 0%)
# 0:00:34 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:00:44 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:00:57 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:01:12 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:01:32 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:01:56 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:02:26 Job 'j-2505161901404f9ab4f9996fb258ec43': running (progress N/A)
# 0:03:04 Job 'j-2505161901404f9ab4f9996fb258ec43': finished (progress 100%)
# ✅ NDWI1_2022-04.tif salvo com sucesso.
# 📥 Iniciando download de NDWI2_2022-04.tif...
# 0:00:00 Job 'j-2505161904464f21ab4528901b1d4258': send 'start'
# 0:00:13 Job 'j-2505161904464f21ab4528901b1d4258': created (progress 0%)
# 0:00:18 Job 'j-2505161904464f21ab4528901b1d4258': created (progress 0%)
# 0:00:25 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:00:33 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:00:43 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:00:55 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:01:11 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:01:30 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:01:54 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:02:24 Job 'j-2505161904464f21ab4528901b1d4258': running (progress N/A)
# 0:03:02 Job 'j-2505161904464f21ab4528901b1d4258': finished (progress 100%)
# ✅ NDWI2_2022-04.tif salvo com sucesso.
# 📥 Iniciando download de LNC_2022-04.tif...
# 0:00:00 Job 'j-2505161907504e9a95da68e5de93e7fe': send 'start'
# 0:00:13 Job 'j-2505161907504e9a95da68e5de93e7fe': created (progress 0%)
# 0:00:18 Job 'j-2505161907504e9a95da68e5de93e7fe': created (progress 0%)
# 0:00:25 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:00:33 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:00:43 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:00:56 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:01:11 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:01:31 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:01:55 Job 'j-2505161907504e9a95da68e5de93e7fe': running (progress N/A)
# 0:02:25 Job 'j-2505161907504e9a95da68e5de93e7fe': finished (progress 100%)
# ✅ LNC_2022-04.tif salvo com sucesso.
# 📥 Iniciando download de MCARI_2022-04.tif...
# 0:00:00 Job 'j-25051619102044a6b3b105c038018b56': send 'start'
# 0:00:14 Job 'j-25051619102044a6b3b105c038018b56': created (progress 0%)
# 0:00:19 Job 'j-25051619102044a6b3b105c038018b56': created (progress 0%)
# 0:00:26 Job 'j-25051619102044a6b3b105c038018b56': created (progress 0%)
# 0:00:34 Job 'j-25051619102044a6b3b105c038018b56': created (progress 0%)
# 0:00:44 Job 'j-25051619102044a6b3b105c038018b56': created (progress 0%)
# 0:00:56 Job 'j-25051619102044a6b3b105c038018b56': queued (progress 0%)
Job 'j-25051619335248ae850a1eb038641d64': queued (progress 0%)
# 0:01:12 Job 'j-25051619335248ae850a1eb038641d64': queued (progress 0%)
# 0:01:31 Job 'j-25051619335248ae850a1eb038641d64': running (progress N/A)
# 0:01:55 Job 'j-25051619335248ae850a1eb038641d64': running (progress N/A)
# 0:02:26 Job 'j-25051619335248ae850a1eb038641d64': running (progress N/A)
# 0:03:03 Job 'j-25051619335248ae850a1eb038641d64': running (progress N/A)
# 0:03:50 Job 'j-25051619335248ae850a1eb038641d64': finished (progress 100%)
# ✅ NDWI2_2022-05.tif salvo com sucesso.
# 📥 Iniciando download de LNC_2022-05.tif...
# 0:00:00 Job 'j-2505161937454cd0a9a80db51eb78eb4': send 'start'
# 0:00:13 Job 'j-2505161937454cd0a9a80db51eb78eb4': created (progress 0%)
# 0:00:18 Job 'j-2505161937454cd0a9a80db51eb78eb4': created (progress 0%)
# 0:00:25 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:00:33 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:00:43 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:00:56 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:01:11 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:01:31 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:01:55 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:02:25 Job 'j-2505161937454cd0a9a80db51eb78eb4': running (progress N/A)
# 0:03:02 Job 'j-2505161937454cd0a9a80db51eb78eb4': finished (progress 100%)
# ✅ LNC_2022-05.tif salvo com sucesso.
# 📥 Iniciando download de MCARI_2022-05.tif...
# 0:00:00 Job 'j-2505161940504633a567cfb0d8394a96': send 'start'
# 0:00:13 Job 'j-2505161940504633a567cfb0d8394a96': created (progress 0%)
# 0:00:19 Job 'j-2505161940504633a567cfb0d8394a96': queued (progress 0%)
# 0:00:25 Job 'j-2505161940504633a567cfb0d8394a96': queued (progress 0%)
# 0:00:33 Job 'j-2505161940504633a567cfb0d8394a96': queued (progress 0%)
# 0:00:43 Job 'j-2505161940504633a567cfb0d8394a96': queued (progress 0%)
# 0:00:56 Job 'j-2505161940504633a567cfb0d8394a96': queued (progress 0%)
# 0:01:12 Job 'j-2505161940504633a567cfb0d8394a96': queued (progress 0%)
# 0:01:31 Job 'j-2505161940504633a567cfb0d8394a96': running (progress N/A)
# 0:01:55 Job 'j-2505161940504633a567cfb0d8394a96': running (progress N/A)
# 0:02:25 Job 'j-2505161940504633a567cfb0d8394a96': finished (progress 100%)
# ✅ MCARI_2022-05.tif salvo com sucesso.
# 📥 Iniciando download de MCARI1_2022-05.tif...
# 0:00:00 Job 'j-2505161943184324bc0a7af09e352e8e': send 'start'
# 0:00:13 Job 'j-2505161943184324bc0a7af09e352e8e': created (progress 0%)
# 0:00:18 Job 'j-2505161943184324bc0a7af09e352e8e': created (progress 0%)
# 0:00:25 Job 'j-2505161943184324bc0a7af09e352e8e': created (progress 0%)
# 0:00:33 Job 'j-2505161943184324bc0a7af09e352e8e': created (progress 0%)
# 0:00:43 Job 'j-2505161943184324bc0a7af09e352e8e': created (progress 0%)
# 0:00:56 Job 'j-2505161943184324bc0a7af09e352e8e': running (progress N/A)
# 0:01:11 Job 'j-2505161943184324bc0a7af09e352e8e': running (progress N/A)
# 0:01:31 Job 'j-2505161943184324bc0a7af09e352e8e': running (progress N/A)
# 0:01:55 Job 'j-2505161943184324bc0a7af09e352e8e': running (progress N/A)
# 0:02:25 Job 'j-2505161943184324bc0a7af09e352e8e': running (progress N/A)
# 0:03:03 Job 'j-2505161943184324bc0a7af09e352e8e': finished (progress 100%)
# ✅ MCARI1_2022-05.tif salvo com sucesso.
# 📥 Iniciando download de GNDVI_2022-05.tif...
# 0:00:00 Job 'j-2505161946234d339ac48531ce96b1c5': send 'start'
# 0:00:14 Job 'j-2505161946234d339ac48531ce96b1c5': created (progress 0%)
# 0:00:19 Job 'j-2505161946234d339ac48531ce96b1c5': created (progress 0%)
# 0:00:26 Job 'j-2505161946234d339ac48531ce96b1c5': created (progress 0%)
# 0:00:34 Job 'j-2505161946234d339ac48531ce96b1c5': created (progress 0%)
# 0:00:44 Job 'j-2505161946234d339ac48531ce96b1c5': created (progress 0%)
# 0:00:56 Job 'j-2505161946234d339ac48531ce96b1c5': running (progress N/A)
# 0:01:12 Job 'j-2505161946234d339ac48531ce96b1c5': running (progress N/A)
# 0:01:31 Job 'j-2505161946234d339ac48531ce96b1c5': running (progress N/A)
# 0:01:55 Job 'j-2505161946234d339ac48531ce96b1c5': running (progress N/A)
# 0:02:26 Job 'j-2505161946234d339ac48531ce96b1c5': running (progress N/A)
# 0:03:03 Job 'j-2505161946234d339ac48531ce96b1c5': finished (progress 100%)
# ✅ GNDVI_2022-05.tif salvo com sucesso.
# 📥 Iniciando download de GOSAVI_2022-05.tif...
# 0:00:00 Job 'j-250516194928491e945401f114862703': send 'start'
# 0:00:14 Job 'j-250516194928491e945401f114862703': created (progress 0%)
# 0:00:19 Job 'j-250516194928491e945401f114862703': created (progress 0%)
# 0:00:26 Job 'j-250516194928491e945401f114862703': created (progress 0%)
# 0:00:34 Job 'j-250516194928491e945401f114862703': created (progress 0%)
# 0:00:44 Job 'j-250516194928491e945401f114862703': running (progress N/A)
# 0:00:56 Job 'j-250516194928491e945401f114862703': running (progress N/A)
# 0:01:12 Job 'j-250516194928491e945401f114862703': running (progress N/A)
# 0:01:31 Job 'j-250516194928491e945401f114862703': running (progress N/A)
# 0:01:55 Job 'j-250516194928491e945401f114862703': running (progress N/A)
# 0:02:25 Job 'j-250516194928491e945401f114862703': running (progress N/A)
# 0:03:03 Job 'j-250516194928491e945401f114862703': finished (progress 100%)
# ✅ GOSAVI_2022-05.tif salvo com sucesso.
#
# 🔄 Processando mês: 2022-06...
# 📥 Iniciando download de NDVI_2022-06.tif...
# 0:00:00 Job 'j-25051619523448eb88666ab5b9bea9c2': send 'start'
# 0:00:14 Job 'j-25051619523448eb88666ab5b9bea9c2': created (progress 0%)
# 0:00:19 Job 'j-25051619523448eb88666ab5b9bea9c2': created (progress 0%)
# 0:00:25 Job 'j-25051619523448eb88666ab5b9bea9c2': created (progress 0%)
# 0:00:33 Job 'j-25051619523448eb88666ab5b9bea9c2': created (progress 0%)
# 0:00:44 Job 'j-25051619523448eb88666ab5b9bea9c2': running (progress N/A)
# 0:00:56 Job 'j-25051619523448eb88666ab5b9bea9c2': running (progress N/A)
# 0:01:12 Job 'j-25051619523448eb88666ab5b9bea9c2': running (progress N/A)
# 0:01:31 Job 'j-25051619523448eb88666ab5b9bea9c2': running (progress N/A)
# 0:01:55 Job 'j-25051619523448eb88666ab5b9bea9c2': running (progress N/A)
# 0:02:25 Job 'j-25051619523448eb88666ab5b9bea9c2': running (progress N/A)
